# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
api_key = "AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)

# %%
def Channel_id(channel_id):
    raw_data=[]
    api_key = "AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw"
    api_service_name = 'youtube'
    api_version = 'v3'
    youtube=build(api_service_name, api_version, developerKey=api_key)
    get_data=youtube.channels().list(part="snippet,contentDetails,statistics",id=channel_id)
    request=get_data.execute()
    for item in request["items"]:
        data={'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"]}
        raw_data.append(data)
    return(pd.DataFrame(raw_data))
Channel_id("UCnKhQkCUS1oCEvjuTfU4xIw")
# Out:
#   channelName subcription      views total_videos               playlist_id
# 0   Tech Boss     3730000  877376037         1404  UUnKhQkCUS1oCEvjuTfU4xIw

# %%
raw_data1=[]
api_key = "AIzaSyBsYY3Vysqe8dbuvalGLLECqh3960Gqahc"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)
get_data=youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id ='UCnKhQkCUS1oCEvjuTfU4xIw')
request=get_data.execute()

for item in request["items"]:
    data={'channel_id':item["id"],
            'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"],
             'description':item["snippet"]["description"],
              'publishedAt':item["snippet"]["publishedAt"],
              'viewCount':item["statistics"]["viewCount"]}
    raw_data1.append(data)
    
pd.DataFrame(raw_data1)
# Out:
#                  channel_id channelName subcription      views total_videos  \
# 0  UCnKhQkCUS1oCEvjuTfU4xIw   Tech Boss     3730000  877376037         1404
#
#                 playlist_id  \
# 0  UUnKhQkCUS1oCEvjuTfU4xIw
#
#                                          description           publishedAt  \
# 0  Tech Boss Channel is an authentic where you ca...  2018-04-12T04:49:58Z
#
#    viewCount
# 0  877376037

# %%
# playlist_id= "UUnKhQkCUS1oCEvjuTfU4xIw"
# def Channel_vid(youtube,channel_id):
#     vid_data=[]
#     get_data=youtube.playlistItems().list(part="snippet,contentDetails",
#                             playlistId=playlist_id, maxResults=40)
#     request=get_data.execute()
#     for item in request["items"]:
#         vid_data.append(item["contentDetails"]["videoId"])
#     next_page=request.get("nextPageToken")
#     while next_page is not None:
#         get_data=youtube.playlistItems().list(part="snippet,contentDetails",
#                             playlistId=playlist_id, maxResults=40)
#         request=get_data.execute()
#         for item in request["items"]:
#             vid_data.append(item["contentDetails"]["videoId"])
#         next_page=request.get("nextPageToken")
#     return vid_data
# Channel_vid(youtube,playlist_id)

# %%
playlist_id= "UUnKhQkCUS1oCEvjuTfU4xIw"
def Channel_vid(youtube,playlist_id):
    vid_data=[]
    get_data=youtube.playlistItems().list(part="snippet,contentDetails",
                            playlistId=playlist_id, maxResults=40)
    request=get_data.execute()
    for item in request["items"]:
        vid_data.append(item["contentDetails"]["videoId"])
    next_page=request.get("nextPageToken")
    while next_page is not None:
        get_data=youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id, 
                maxResults=40,
                pageToken = next_page)
        request=get_data.execute()
        for item in request["items"]:
            vid_data.append(item["contentDetails"]["videoId"])
        next_page=request.get("nextPageToken")
    return vid_data
vid_data = Channel_vid(youtube,playlist_id)

# %%
len(vid_data)
# Out:
# 1405

# %%
def video_info(youtube,vid_data):
    vid_info=[]
    for i in range(0, len(vid_data),40):
        get_data=youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(vid_data[i:i+40]))
        value=get_data.execute()
        for vid in value['items']:
            details={'snippet':['chennelTitle','Title','description','tags','publishedAt'],
                    'statistics':['viewCount','likeCount','favouriteCount','commentCount'],
                    'contentDetails':['duration','definition','caption']
                    }
            info={}
            info['video_id']= vid['id']
            for j in details.keys():
                for k in details[j]:
                    try:
                        info[k] = vid[j][k]
                    except:
                        info[k] = None
            vid_info.append(info)
    return pd.DataFrame(vid_info)
vid_df = video_info(youtube,vid_data)

# %%
vid_df
# Out:
#          video_id chennelTitle Title  \
# 0     6rBtYBtrhwA         None  None
# 1     M6qK-Q6pKdM         None  None
# 2     sOjYYhXKcGw         None  None
# 3     SeDvR2651Ek         None  None
# 4     Qm6H-QfwkwE         None  None
# ...           ...          ...   ...
# 1400  5jQsr0PfNCQ         None  None
# 1401  HUYng0m8DC8         None  None
# 1402  ztLI7LGJbG8         None  None
# 1403  vBqO4gCIEKk         None  None
# 1404  HRxA_kAVBFM         None  None
#
#                                             description  \
# 0     ---\nMedia Partner : Adada Creators\nEmail : t...
# 1     #TecnoPhantomVFold #TechBoss #Tecno \n\n---\nM...
# 2     Location Courtesy:\nVasantham Home Appliances\...
# 3     ---\nMedia Partner : Adada Creators\nEmail : t...
# 4     ---\nMedia Partner : Adada Creators\nEmail : t...
# ...                                                 ...
# 1400  Best Buy Link : http://fkrt.it/ci4k2KNNNN\n\nஒ...
# 1401  Engineering Counsellingக்கு ஆன்லைனில் அப்பளை ச...
# 1402  Best Buy Link:\n\nBlackt Electrotech : (BT81D)...
# 1403  Buy Here:\nhttps://goo.gl/93Hesu\nhttps://goo....
# 1404  Link : https://amzn.to/2vG61ej\n\nUnboxing & R...
#
#                                                    tags           publishedAt  \
# 0                                            [Techboss]  2023-05-13T11:34:00Z
# 1     [Techboss, Tecno Phantom V Fold, Cheapest Fold...  2023-05-13T03:54:24Z
# 2     [Techboss, how to buy ac ?, how to buy air con...  2023-05-12T05:00:09Z
# 3                                            [Techboss]  2023-05-11T04:31:00Z
# 4                                            [Techboss]  2023-05-10T12:13:19Z
# ...                                                 ...                   ...
# 1400  [Jio, Unboxing & Review, Asus Zenfone Max, Zen...  2018-05-05T08:23:41Z
# 1401  [Engineering Counselling, tnea 2018, tnea appl...  2018-05-04T12:53:52Z
# 1402  [Home Automation, Unboxing, sensor light, sens...  2018-05-04T06:19:32Z
# 1403  [Unboxing & Review, FeiyuTech Vimble 2, Unboxi...  2018-05-02T06:20:42Z
# 1404  [Unboxing & Review, Zoom H1 Recorder, Digital ...  2018-04-26T02:31:09Z
#
#      viewCount likeCount favouriteCount commentCount duration definition  \
# 0       525762     67719           None          193    PT42S         hd
# 1       236734     13172           None          599  PT10M5S         hd
# 2       111247     10218           None          489  PT8M50S         hd
# 3       448948     51288           None          238    PT37S         hd
# 4       346782     38703           None          249    PT35S         hd
# ...        ...       ...            ...          ...      ...        ...
# 1400      9663       360           None           40  PT10M7S         hd
# 1401      3290       134           None           15  PT5M38S         hd
# 1402     49234       871           None           35  PT2M51S         hd
# 1403     21804       756           None           53  PT6M39S         hd
# 1404     44256      2733           None          261   PT6M8S         hd
#
#      caption
# 0      false
# 1       true
# 2       true
# 3      false
# 4      false
# ...      ...
# 1400   false
# 1401   false
# 1402   false
# 1403   false
# 1404   false
#
# [1405 rows x 13 columns]

# %%
 def vid_comments(youtube, vid_data):
    all_com = []
    for i in vid_data:
        try:
            val = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=i,
                maxResults=10
            )

            data = val.execute()
            if 'items' in data:
                all_comments = [j['snippet']['topLevelComment']['snippet']['textOriginal'] for j in data['items']]
            else:
                all_comments = None
            comments_data = {'video_id': i, 'comments': all_comments}
            all_com.append(comments_data)
        except HttpError as e:
            if e.resp.status in [403, 400]:
                comments_data = {'video_id': i, 'comments': None}
                all_com.append(comments_data)
            else:
                raise e
    return pd.DataFrame(all_com)
all_com = vid_comments(youtube, vid_data)
all_com
# Out:
#          video_id                                           comments
# 0     6rBtYBtrhwA  [😂😂🎉, Bro 1300rs t800 ultra smartwatch review,...
# 1     M6qK-Q6pKdM  [Samsung galaxy book 3 pro 360 vs apple laptop...
# 2     sOjYYhXKcGw  [Don't Miss the End..😂, பாய் நக்கல்யா உனக்கு 😅...
# 3     SeDvR2651Ek  [தல உங்கள சுத்தி இருக்குற எல்லாருமே நடுத்தர மக...
# 4     Qm6H-QfwkwE  [Bro marshall speaker review podanga, For Sams...
# ...           ...                                                ...
# 1400  5jQsr0PfNCQ  [Currently I am using same Asus Zenfone max 1 ...
# 1401  HUYng0m8DC8  [Hi, Old tech boss to current tech boss awesom...
# 1402  ztLI7LGJbG8  [Intha video yanakku ippo recommend aaguthu 4 ...
# 1403  vBqO4gCIEKk  [3.m, வாழ்த்துக்கள்🎉🎊🎉🎊🎉🎊🎉🎊, Bro mobile la joy...
# 1404  HRxA_kAVBFM  [2023 😉, Pro legends watch on 2023, Legends ar...
#
# [1405 rows x 2 columns]

# %%
vid_comments = pd.DataFrame(all_com)

# %%
vid_comments.head()
# Out:
#       video_id                                           comments
# 0  6rBtYBtrhwA  [😂😂🎉, Bro 1300rs t800 ultra smartwatch review,...
# 1  M6qK-Q6pKdM  [Samsung galaxy book 3 pro 360 vs apple laptop...
# 2  sOjYYhXKcGw  [Don't Miss the End..😂, பாய் நக்கல்யா உனக்கு 😅...
# 3  SeDvR2651Ek  [தல உங்கள சுத்தி இருக்குற எல்லாருமே நடுத்தர மக...
# 4  Qm6H-QfwkwE  [Bro marshall speaker review podanga, For Sams...
