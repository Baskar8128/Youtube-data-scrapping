# %%
import pandas as pd
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# %%
api_key = "AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)

# %%
def Channel_id(channel_id):
    raw_data=[]
    api_key = "AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw"
    api_service_name = 'youtube'
    api_version = 'v3'
    youtube=build(api_service_name, api_version, developerKey=api_key)
    get_data=youtube.channels().list(part="snippet,contentDetails,statistics",id=channel_id)
    request=get_data.execute()
    for item in request["items"]:
        data={'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"]}
        raw_data.append(data)
    return(pd.DataFrame(raw_data))
Channel_id("UCnKhQkCUS1oCEvjuTfU4xIw")
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# C:\Windows\Temp\ipykernel_14020\3046075694.py in <module>
#      15         raw_data.append(data)
#      16     return(pd.DataFrame(raw_data))
# ---> 17 Channel_id("UCnKhQkCUS1oCEvjuTfU4xIw")
#
# C:\Windows\Temp\ipykernel_14020\3046075694.py in Channel_id(channel_id)
#       6     youtube=build(api_service_name, api_version, developerKey=api_key)
#       7     get_data=youtube.channels().list(part="snippet,contentDetails,statistics",id=channel_id)
# ----> 8     request=get_data.execute()
#       9     for item in request["items"]:
#      10         data={'channelName':item["snippet"]["title"],
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&id=UCnKhQkCUS1oCEvjuTfU4xIw&key=AIzaSyD6a-fcovIUsEx_x54oJqxR7Kp6W_E2dqw&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
raw_data1=[]
api_key = "AIzaSyBsYY3Vysqe8dbuvalGLLECqh3960Gqahc"
api_service_name = 'youtube'
api_version = 'v3'
youtube=build(api_service_name, api_version, developerKey=api_key)
get_data=youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id ='UCnKhQkCUS1oCEvjuTfU4xIw')
request=get_data.execute()

for item in request["items"]:
    data={'channel_id':item["id"],
            'channelName':item["snippet"]["title"],
             'subcription':item["statistics"]["subscriberCount"],
             'views':item["statistics"]["viewCount"],
             'total_videos':item["statistics"]["videoCount"],
             'playlist_id':item["contentDetails"]["relatedPlaylists"]["uploads"],
             'description':item["snippet"]["description"],
              'publishedAt':item["snippet"]["publishedAt"],
              'viewCount':item["statistics"]["viewCount"]}
    raw_data1.append(data)
    
pd.DataFrame(raw_data1)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# C:\Windows\Temp\ipykernel_14020\951424184.py in <module>
#       7     part="snippet,contentDetails,statistics",
#       8     id ='UCnKhQkCUS1oCEvjuTfU4xIw')
# ----> 9 request=get_data.execute()
#      10
#      11 for item in request["items"]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=snippet%2CcontentDetails%2Cstatistics&id=UCnKhQkCUS1oCEvjuTfU4xIw&key=AIzaSyBsYY3Vysqe8dbuvalGLLECqh3960Gqahc&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
# playlist_id= "UUnKhQkCUS1oCEvjuTfU4xIw"
# def Channel_vid(youtube,channel_id):
#     vid_data=[]
#     get_data=youtube.playlistItems().list(part="snippet,contentDetails",
#                             playlistId=playlist_id, maxResults=40)
#     request=get_data.execute()
#     for item in request["items"]:
#         vid_data.append(item["contentDetails"]["videoId"])
#     next_page=request.get("nextPageToken")
#     while next_page is not None:
#         get_data=youtube.playlistItems().list(part="snippet,contentDetails",
#                             playlistId=playlist_id, maxResults=40)
#         request=get_data.execute()
#         for item in request["items"]:
#             vid_data.append(item["contentDetails"]["videoId"])
#         next_page=request.get("nextPageToken")
#     return vid_data
# Channel_vid(youtube,playlist_id)

# %%
playlist_id= "UUnKhQkCUS1oCEvjuTfU4xIw"
def Channel_vid(youtube,playlist_id):
    vid_data=[]
    get_data=youtube.playlistItems().list(part="snippet,contentDetails",
                            playlistId=playlist_id, maxResults=40)
    request=get_data.execute()
    for item in request["items"]:
        vid_data.append(item["contentDetails"]["videoId"])
    next_page=request.get("nextPageToken")
    while next_page is not None:
        get_data=youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id, 
                maxResults=40,
                pageToken = next_page)
        request=get_data.execute()
        for item in request["items"]:
            vid_data.append(item["contentDetails"]["videoId"])
        next_page=request.get("nextPageToken")
    return vid_data
vid_data = Channel_vid(youtube,playlist_id)

# %%
len(vid_data)
# Out:
# 1403

# %%
def video_info(youtube,vid_data):
    vid_info=[]
    for i in range(0, len(vid_data),40):
        get_data=youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(vid_data[i:i+40]))
        value=get_data.execute()
        for vid in value['items']:
            details={'snippet':['chennelTitle','Title','description','tags','publishedAt'],
                    'statistics':['viewCount','likeCount','favouriteCount','commentCount'],
                    'contentDetails':['duration','definition','caption']
                    }
            info={}
            info['video_id']= vid['id']
            for j in details.keys():
                for k in details[j]:
                    try:
                        info[k] = vid[j][k]
                    except:
                        info[k] = None
            vid_info.append(info)
    return pd.DataFrame(vid_info)
vid_df = video_info(youtube,vid_data)

# %%
vid_df
# Out:
#          video_id chennelTitle Title  \
# 0     sOjYYhXKcGw         None  None
# 1     SeDvR2651Ek         None  None
# 2     Qm6H-QfwkwE         None  None
# 3     jMdr5-_L9fI         None  None
# 4     vUIcG5gLxQs         None  None
# ...           ...          ...   ...
# 1398  5jQsr0PfNCQ         None  None
# 1399  HUYng0m8DC8         None  None
# 1400  ztLI7LGJbG8         None  None
# 1401  vBqO4gCIEKk         None  None
# 1402  HRxA_kAVBFM         None  None
#
#                                             description  \
# 0     Location Courtesy:\nVasantham Home Appliances\...
# 1     ---\nMedia Partner : Adada Creators\nEmail : t...
# 2     ---\nMedia Partner : Adada Creators\nEmail : t...
# 3     ---\nMedia Partner : Adada Creators\nEmail : t...
# 4     #PocoF5 #TechBoss #Poco\n\nPoco F5 --- 8GB + 2...
# ...                                                 ...
# 1398  Best Buy Link : http://fkrt.it/ci4k2KNNNN\n\nஒ...
# 1399  Engineering Counsellingக்கு ஆன்லைனில் அப்பளை ச...
# 1400  Best Buy Link:\n\nBlackt Electrotech : (BT81D)...
# 1401  Buy Here:\nhttps://goo.gl/93Hesu\nhttps://goo....
# 1402  Link : https://amzn.to/2vG61ej\n\nUnboxing & R...
#
#                                                    tags           publishedAt  \
# 0     [Techboss, how to buy ac ?, how to buy air con...  2023-05-12T05:00:09Z
# 1                                            [Techboss]  2023-05-11T04:31:00Z
# 2                                            [Techboss]  2023-05-10T12:13:19Z
# 3                                            [Techboss]  2023-05-10T04:31:00Z
# 4     [Techboss, poco f5 unboxing, poco f5 unboxing ...  2023-05-09T13:02:25Z
# ...                                                 ...                   ...
# 1398  [Jio, Unboxing & Review, Asus Zenfone Max, Zen...  2018-05-05T08:23:41Z
# 1399  [Engineering Counselling, tnea 2018, tnea appl...  2018-05-04T12:53:52Z
# 1400  [Home Automation, Unboxing, sensor light, sens...  2018-05-04T06:19:32Z
# 1401  [Unboxing & Review, FeiyuTech Vimble 2, Unboxi...  2018-05-02T06:20:42Z
# 1402  [Unboxing & Review, Zoom H1 Recorder, Digital ...  2018-04-26T02:31:09Z
#
#      viewCount likeCount favouriteCount commentCount duration definition  \
# 0        58833      7367           None          358  PT8M50S         hd
# 1       373247     44259           None          195    PT37S         hd
# 2       291653     34001           None          232    PT35S         hd
# 3       702785    103664           None          134    PT59S         hd
# 4       237001     12952           None          693  PT4M58S         hd
# ...        ...       ...            ...          ...      ...        ...
# 1398      9650       359           None           40  PT10M7S         hd
# 1399      3279       134           None           15  PT5M38S         hd
# 1400     49215       871           None           35  PT2M51S         hd
# 1401     21772       754           None           52  PT6M39S         hd
# 1402     44180      2730           None          260   PT6M8S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4       true
# ...      ...
# 1398   false
# 1399   false
# 1400   false
# 1401   false
# 1402   false
#
# [1403 rows x 13 columns]

# %%
def vid_comments(youtube,vid_data):
    all_com = []
    for i in vid_data:
        val = youtube.commentThreads().list(
        part="snippet,replies",
        videoId=i,
        maxResults = 40)
        
        data = val.execute()
        if 'items' in data:
            all_comments = [j['snippet']['topLevelComment']['snippet']['textOriginal'] for j in data['items']]
            comments_data = {'video_id': i, 'comments': all_comments}
            all_com.append(comments_data)
    return pd.DataFrame(all_com)
all_com = vid_comments(youtube,vid_data)

# %%
def vid_comments(youtube, vid_data):
    all_com = []
    for i in vid_data:
        try:
            val = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=i,
                maxResults=10
            )

            data = val.execute()
            if 'items' in data:
                all_comments = [j['snippet']['topLevelComment']['snippet']['textOriginal'] for j in data['items']]
            else:
                all_comments = None
            comments_data = {'video_id': i, 'comments': all_comments}
            all_com.append(comments_data)
        except HttpError as e:
            if e.resp.status in [403, 400]:
                comments_data = {'video_id': i, 'comments': None}
                all_com.append(comments_data)
            else:
                raise e
    return pd.DataFrame(all_com)
all_com = vid_comments(youtube, vid_data)

# %%
all_com
# Out:
#          video_id comments
# 0     sOjYYhXKcGw     None
# 1     SeDvR2651Ek     None
# 2     Qm6H-QfwkwE     None
# 3     jMdr5-_L9fI     None
# 4     vUIcG5gLxQs     None
# ...           ...      ...
# 1398  5jQsr0PfNCQ     None
# 1399  HUYng0m8DC8     None
# 1400  ztLI7LGJbG8     None
# 1401  vBqO4gCIEKk     None
# 1402  HRxA_kAVBFM     None
#
# [1403 rows x 2 columns]
